# %% [markdown]
# # 1.Content的使用
#
# 举例：保存多模态的数据,使用字典列表

# %%
from langchain.chat_models import init_chat_model
import base64
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv(override=True)

model = init_chat_model(
    model="qwen3.5-flash",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL")
)

# response = model.invoke("介绍一下你自己")
# print(response.content)
#将一张本地图片转换成Base64编码的Data URI字符串，方便在文本中嵌入图片数据
def encode_image(img_path, img_type='jpeg'):
     with open(img_path,"rb") as img_file:
         return  f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode("utf-8")}"

#图像路径
img_path = "img.png"

# # 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
         HumanMessage(
             content=[
                {"type":"text","text":"这张图里是什么？"},
                {
                  "type":"image_url","image_url":base64_image
                }
             ]
         )
     ]
 )
#
#
#
print(response.content)
# Out:
# 这张图片展示的是一瓶**化妆品**，具体来说是一瓶**粉底液**。
#
# 从外观设计来看，它非常像 **雅诗兰黛 (Estée Lauder)** 品牌的经典产品 —— **DW 持妆粉底液 (Double Wear Stay-in-Place Makeup)**。
#
# 主要特征包括：
# *   **瓶身**：透明的方形玻璃瓶，可以看到里面米色/肤色的液体。
# *   **包装**：配有金色的按压泵头和瓶盖，显得比较高档。
# *   **背景**：暖色调的背景光，典型的商业产品展示拍摄风格。

# %%
from langchain.chat_models import init_chat_model
import base64
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv(override=True)

model = init_chat_model(
    model="kimi-k2.6",
    model_provider="openai",
    api_key=os.getenv("MOONSHOT_API_KEY"),
    base_url=os.getenv("MOONSHOT_BASE_URL")
)
#将一张本地图片转换成Base64编码的Data URI字符串，方便在文本中嵌入图片数据
def encode_image(img_path):
     with open(img_path,"rb") as img_file:
         return base64.b64encode(img_file.read()).decode("utf-8")
#图像路径
img_path = "img.png"
#获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        HumanMessage(
           content_blocks=[
               {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image',
                    'base64': base64_image,
                     'mime_type': 'image/png',
                 }
             ]
         )
     ]
 )
print(response.content)
# Out:
# 这张图里是一瓶**粉底液**（或类似的液体彩妆/护肤品）。
#
# 具体特征包括：
# *   **瓶身**：透明的方形玻璃瓶，可以看到里面浅肤色或米色的液体。
# *   **瓶盖/泵头**：顶部有金色的装饰和按压泵头，看起来比较精致。
# *   **整体风格**：产品摆放在一个纯色（米色/浅黄色）的背景上，光线柔和明亮，在左侧投下了阴影，整体给人一种高端、简约的感觉。
#
# 从外观判断，这很可能是某个高端美妆品牌的底妆产品。

# %% [markdown]
# 作为对比:上面使用的是月之暗面的大模型，下面使用阿里云百炼千问大模型

# %%
from langchain.chat_models import init_chat_model
import base64
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv(override=True)

model = init_chat_model(
    model="qwen3.5-flash",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL")
)

# response = model.invoke("介绍一下你自己")
# print(response.content)
#将一张本地图片转换成Base64编码的Data URI字符串，方便在文本中嵌入图片数据
def encode_image(img_path):
     with open(img_path,"rb") as img_file:
         return base64.b64encode(img_file.read()).decode("utf-8")

#图像路径
img_path = "img.png"

# # 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        HumanMessage(
           content_blocks=[
               {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image',
                    'base64': base64_image,
                     'mime_type': 'image/png',
                 }
             ]
         )
     ]
 )
#
#
#
print(response.content)
# Out:
# 这张图片展示了一瓶**粉底液**。
#
# 以下是关于它的详细观察：
#
# 1.  **产品外观**：
#     *   它是一个长方体的透明玻璃瓶，里面装着米色或浅棕色的液体，这是典型的粉底液颜色。
#     *   瓶盖和泵头部分是金色的，看起来很有光泽，给人一种精致、高端的感觉。
#     *   瓶身中间有一个金色的标签，虽然字迹有些模糊，但从整体设计风格（特别是方形瓶身和金色盖子）来看，这非常像**雅诗兰黛（Estée Lauder）的 Double Wear 持妆粉底液**。
#
# 2.  **背景与光影**：
#     *   背景是纯净的暖色调（米色或浅棕色），突出了产品本身。
#     *   光线从左上方照射下来，在瓶子的右侧投下了长长的阴影，增强了立体感。

# %% [markdown]
# 举例2：输出的格式化

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os
from rich import print as rprint

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
    extra_body={"thinking":{"type":"enabled"}},
)

response = model.invoke("你好，一句话回答")
rprint(response)
# Out:
# AIMessage(
#     content='你好，有什么我可以帮你一句话回答的吗？',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '用户问得很简单，就是让我用一句话回答。这个要求很明确，不需要展开或者解释。既然用户没有具体提问内容，我就先表明自己
# 已经准备就绪，可以随时接收问题。用简洁直接的方式回应，既符合指令也保持友好态度。'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 66,
#             'prompt_tokens': 8,
#             'total_tokens': 74,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 56,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 8
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': '08f0704b-6330-414a-9ea7-065d3c011110',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019fa228-6371-7831-b2d3-14de630efc33-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 8,
#         'output_tokens': 66,
#         'total_tokens': 74,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 56}
#     }
# )

# %% [markdown]
# 格式化输出对比

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
    extra_body={"thinking":{"type":"enabled"}},
)

response = model.invoke("你好，一句话回答")
print('=' * 20, '-> response <-', '=' * 20)
print(response)
print('=' * 20, '-> response.content <-', '=' * 20)
print(response.content)
print('=' * 20, '-> response.content_blocks <-', '=' * 20)
print(response.content_blocks)
# Out:
# ==================== -> response <- ====================
# content='你好，请问有什么可以帮你的？' additional_kwargs={'refusal': None, 'reasoning_content': '用户说“你好，一句话回答”，看起来是希望我用一句话回应。那我就用一句简洁的问候来回复吧，既符合用户的要求，又显得友好自然。'} response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 8, 'total_tokens': 52, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 35, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '0fca30f0-730b-4735-a329-b8dd4e4b4ab3', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019fa232-10fa-7f93-86b2-3ff85b296e21-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 44, 'total_tokens': 52, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 35}}
# ==================== -> response.content <- ====================
# 你好，请问有什么可以帮你的？
# ==================== -> response.content_blocks <- ====================
# [{'type': 'reasoning', 'reasoning': '用户说“你好，一句话回答”，看起来是希望我用一句话回应。那我就用一句简洁的问候来回复吧，既符合用户的要求，又显得友好自然。'}, {'type': 'text', 'text': '你好，请问有什么可以帮你的？'}]
